# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def readResult(K):
    with open("../result/K-%d.out" % K, "r") as f:
        lines = f.readlines()
        clusters = [[float(xi) for xi in line.split()] for line in lines[:K]]
        c_idx = [int(c) for c in lines[K].split()]
        
    return clusters, c_idx
def readPoints():
    with open("../data/data.csv", "r") as f:
        lines = f.readlines()[1:]
        points = [[float(xi) for xi in line.split(',')[:3]] for line in lines]
        label = [int(float(line.split(',')[-1])) for line in lines]
    return points, label
points, label = readPoints()

# %%
points, label = readPoints()

# %%
import pylab as p
import mpl_toolkits.mplot3d.axes3d as p3
color = 'bgrcmykw'
fig = None
def plotCluster(points, idx):
    global fig
    fig=p.figure()
    ax = p3.Axes3D(fig)
    x, y, z = list(zip(*points))
    c = [color[i] for i in idx]
    ax.scatter(x, y, z, c=c)
    
def plotClusterLine(points, idx, clusters):
    fig, axl = plt.subplots(subplot_kw={'projection': '3d'})
    for i, point in enumerate(points):
        x, y, z = list(zip(*[point, clusters[idx[i]]]))
        axl.plot(x, y, z, color=color[idx[i]])

def dist(p1, p2):
    d = 0.0
    for i in range(len(p1)):
        d += (p1[i] - p2[i]) ** 2
    return d

# %%
c2, c2_idx = readResult(2)
plotCluster(points, c2_idx)
plotClusterLine(points, c2_idx, c2)
# Out:
# <img src="data:image/png;base64,..." width="405.5">
# <img src="data:image/png;base64,..." width="389">

# %%
fig.savefig("k2.eps", dpi=1200)
plt.savefig("k2line.eps", dpi=1200)

# %%
c3, c3_idx = readResult(3)
plotCluster(points, c3_idx)
plotClusterLine(points, c3_idx, c3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
fig.savefig("k33.eps", dpi=1200)

# %%
fig.savefig("k3.eps", dpi=1200)

# %%
c4, c4_idx = readResult(4)
plotCluster(points, c4_idx)
plotClusterLine(points, c4_idx, c4)
plotCluster(points[0:1], [6])
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
fig.savefig("k4.eps", dpi=1200)
plt.savefig("k4line.eps", dpi=1200)

# %%
plotCluster(points, label)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
distance = [0.838435, 0.627881, 0.546652, 0.491255, 0.440874, 0.411244, 0.395966]
idx = [ i+2 for i in range(len(distance))]

# %%
# %matplotlib inline

# %%
plt.plot(idx, distance, 'o-')
plt.ylabel("AVG distance")
plt.xlabel("# of clusters")
plt.savefig("../../img/random/avgdist.eps", dpi=1200)
